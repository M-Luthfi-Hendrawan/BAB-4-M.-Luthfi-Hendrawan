# %% [markdown]
# <a href="https://colab.research.google.com/github/M-Luthfi-Hendrawan/BAB-4-M.-Luthfi-Hendrawan/blob/main/F0403251104_M.%20Luthfi%20Hendarwan_BAB4_Post%20Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Halo, Bang")
# Out:
# Halo, Bang
